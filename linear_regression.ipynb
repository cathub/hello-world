# %% [markdown]
# <a href="https://colab.research.google.com/github/cathub/hello-world/blob/master/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])
model.compile(optimizer='sgd', loss = 'mean_squared_error')

xs = np.array([1,2,3,4,5,6], float)
ys = np.array([1,3,5,7,9,11], float)

model.fit(xs, ys, epochs = 500)

print(model.predict([10]))
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 10ms/sample - loss: 122.7260
# Epoch 2/500
# 6/6 [==============================] - 0s 382us/sample - loss: 57.0718
# Epoch 3/500
# 6/6 [==============================] - 0s 362us/sample - loss: 26.6832
# Epoch 4/500
# 6/6 [==============================] - 0s 385us/sample - loss: 12.6164
# Epoch 5/500
# 6/6 [==============================] - 0s 372us/sample - loss: 6.1039
# Epoch 6/500
# 6/6 [==============================] - 0s 451us/sample - loss: 3.0878
# Epoch 7/500
# 6/6 [==============================] - 0s 376us/sample - loss: 1.6900
# Epoch 8/500
# 6/6 [==============================] - 0s 413us/sample - loss: 1.0411
# Epoch 9/500
# 6/6 [==============================] - 0s 346us/sample - loss: 0.7389
# Epoch 10/500
# 6/6 [==============================] - 0s 355us/sample - loss: 0.5972
# Epoch 11/500
# 6/6 [==============================] - 0s 369us/sample - loss: 0.5297
# Epoch 12/500
# ...
